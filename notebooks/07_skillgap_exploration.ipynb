# %%
# =========================================
# Skill Gap Analyzer
# 07_skillgap_exploration.ipynb
# Cell 1: Raw Data Inspection
# =========================================

import os

RAW_PATH = "/content"

print("Files available in raw data folder:\n")
for file in os.listdir(RAW_PATH):
    print("-", file)
# Out:
# Files available in raw data folder:
#
# - .config
# - college_student_placement_dataset.csv
# - UpdatedResumeDataSet.csv
# - detailed_data.csv
# - DataScientist.csv
# - indian_student_placement_data.csv
# - region_mumbai.csv
# - hack_startup_funding.csv
# - data_scientists_salaries_from_reddit.csv
# - job_placement.csv
# - placementdata.csv
# - monster_com-job_sample.csv
# - Placement.csv
# - startup_funding.csv
# - placement_companies.csv
# - sample_data

# %%
# =========================================
# Cell 2: Load Job & Resume Skill Datasets
# =========================================

import pandas as pd

# Load job skills dataset
job_df = pd.read_csv("monster_com-job_sample.csv")

print("JOB DATASET")
print("Shape:", job_df.shape)
print("Columns:", job_df.columns.tolist())
display(job_df.head(3))

# Load resume dataset
resume_df = pd.read_csv("UpdatedResumeDataSet.csv")

print("\nRESUME DATASET")
print("Shape:", resume_df.shape)
print("Columns:", resume_df.columns.tolist())
display(resume_df.head(3))
# Out:
# JOB DATASET
# Shape: (22000, 14)
# Columns: ['country', 'country_code', 'date_added', 'has_expired', 'job_board', 'job_description', 'job_title', 'job_type', 'location', 'organization', 'page_url', 'salary', 'sector', 'uniq_id']
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...

# %%
# =========================================
# Cell 3: Skill Text Structure Analysis
# =========================================

# Inspect job description text
print("JOB DESCRIPTION SAMPLE:\n")
print(job_df["job_description"].iloc[0][:1000])

print("\n" + "="*80 + "\n")

# Inspect resume text
print("RESUME TEXT SAMPLE:\n")
print(resume_df["Resume"].iloc[0][:1000])
# Out:
# JOB DESCRIPTION SAMPLE:
#
# ...
